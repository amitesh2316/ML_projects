# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()

diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
print(diabetes.feature_names)

diabetes.DESCR
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# ...

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
diabetes.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
df =pd.DataFrame(data=diabetes.data,columns=diabetes.feature_names)

print(df)

df['DiseaseProgression']=diabetes.target

print(df)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  DiseaseProgression
# 0 -0.002592  0.019908 -0.017646               151.0
# 1 -0.039493 -0.068330 -0.092204                75.0
# 2 -0.002592  0.002864 -0.025930               141.0
# 3  0.034309  0.022692 -0.009362               206.0
# 4 -0.002592 -0.031991 -0.046641               135.0

# %%
df.shape
# Out:
# (442, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# ...

# %%
sns.heatmap(df.isnull())

# %%
dfcor = df.corr()
dfcor
# Out:
#                          age       sex       bmi        bp        s1  \
# age                 1.000000  0.173737  0.185085  0.335427  0.260061
# sex                 0.173737  1.000000  0.088161  0.241013  0.035277
# bmi                 0.185085  0.088161  1.000000  0.395415  0.249777
# bp                  0.335427  0.241013  0.395415  1.000000  0.242470
# s1                  0.260061  0.035277  0.249777  0.242470  1.000000
# s2                  0.219243  0.142637  0.261170  0.185558  0.896663
# s3                 -0.075181 -0.379090 -0.366811 -0.178761  0.051519
# s4                  0.203841  0.332115  0.413807  0.257653  0.542207
# s5                  0.270777  0.149918  0.446159  0.393478  0.515501
# s6                  0.301731  0.208133  0.388680  0.390429  0.325717
# DiseaseProgression  0.187889  0.043062  0.586450  0.441484  0.212022
#
#                           s2        s3        s4        s5        s6  \
# ...

# %%
sns.heatmap(dfcor)

# %%
plt.boxplot(df["age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a54c2ea470>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a54c2eab00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a54c2ea048>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a54c2eaf28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a54c2f5518>],
#  'means': []}

# %%
plt.boxplot(df["sex"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a54c348ba8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a54c348ef0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a54c3487b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a54c356978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a54c356cc0>],
#  'means': []}

# %%
plt.boxplot(df["bmi"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a54c3ae3c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a54c3aeac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a54c3a1f98>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a54c3aeef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a54c3b84e0>],
#  'means': []}

# %%
plt.boxplot(df["bp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a54c406e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a54c413828>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a54c406cf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a54c413eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a54c413f98>],
#  'means': []}

# %%
print(plt.boxplot(df["s1"]))
print(plt.boxplot(df["s2"]))
print(plt.boxplot(df["s3"]))
print(plt.boxplot(df["s4"]))
print(plt.boxplot(df["s5"]))
print(plt.boxplot(df["s6"]))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D object at 0x000001A54C46D5F8>, <matplotlib.lines.Line2D object at 0x000001A54C46D9B0>], 'caps': [<matplotlib.lines.Line2D object at 0x000001A54C46DCF8>, <matplotlib.lines.Line2D object at 0x000001A54C46DDD8>], 'boxes': [<matplotlib.lines.Line2D object at 0x000001A54C46D208>], 'medians': [<matplotlib.lines.Line2D object at 0x000001A54C4763C8>], 'fliers': [<matplotlib.lines.Line2D object at 0x000001A54C476710>], 'means': []}
# {'whiskers': [<matplotlib.lines.Line2D object at 0x000001A54C476DD8>, <matplotlib.lines.Line2D object at 0x000001A54C476EF0>], 'caps': [<matplotlib.lines.Line2D object at 0x000001A54C4834E0>, <matplotlib.lines.Line2D object at 0x000001A54C483828>], 'boxes': [<matplotlib.lines.Line2D object at 0x000001A54C46D0B8>], 'medians': [<matplotlib.lines.Line2D object at 0x000001A54C483B70>], 'fliers': [<matplotlib.lines.Line2D object at 0x000001A54C483EB8>], 'means': []}
# ...

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
import seaborn as sns
df.hist()
pyplot.show()

# %%
scatter_matrix(df)
pyplot.show()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
# array([[0.80050009, 1.06548848, 1.29708846, ..., 0.41855058, 0.37098854,
#         0.01471948],
#        [0.03956713, 0.93853666, 1.08218016, ..., 1.43655059, 1.93847913,
#         1.00165882],
#        [1.79330681, 1.06548848, 0.93453324, ..., 0.06020733, 0.54515416,
#         0.14457991],
#        ...,
#        [0.87686984, 1.06548848, 0.33441002, ..., 0.98558469, 0.32567395,
#         0.26145431],
#        [0.9560041 , 0.93853666, 0.82123474, ..., 0.93615545, 0.54515416,
#         0.88131756],
#        [0.9560041 , 0.93853666, 1.53537419, ..., 0.08871747, 0.06442552,
#         1.23540761]])

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 58, 123, 123, 123, 216, 230, 230, 256, 260, 261, 269, 322, 336,
#        367, 441], dtype=int64), array([6, 4, 5, 7, 7, 4, 5, 2, 6, 6, 6, 7, 7, 2, 6], dtype=int64))

# %%
df1 = df[(z < 3).all(axis=1)]

# %%
df.shape
# Out:
# (442, 11)

# %%
df1.shape
# Out:
# (430, 11)

# %%
x = df1.iloc[:,0:10]

# %%
x
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
y = df1.iloc[:,-1]

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
# 5       97.0
# 6      138.0
# 7       63.0
# 8      110.0
# 9      310.0
# 10     101.0
# 11      69.0
# 12     179.0
# 13     185.0
# 14     118.0
# 15     171.0
# 16     166.0
# 17     144.0
# 18      97.0
# 19     168.0
# 20      68.0
# 21      49.0
# 22      68.0
# 23     245.0
# 24     184.0
# 25     202.0
# 26     137.0
# 27      85.0
# 28     131.0
# 29     283.0
#        ...
# 411    136.0
# 412    261.0
# 413    113.0
# 414    131.0
# 415    174.0
# 416    257.0
# 417     55.0
# 418     84.0
# 419     42.0
# 420    146.0
# 421    212.0
# 422    233.0
# 423     91.0
# 424    111.0
# 425    152.0
# 426    120.0
# 427     67.0
# 428    310.0
# 429     94.0
# 430    183.0
# 431     66.0
# 432    173.0
# 433     72.0
# 434     49.0
# 435     64.0
# 436     48.0
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# Name: DiseaseProgression, Length: 430, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=47)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([  53.54401946, -224.11070855,  409.62245995,  355.64432999,
#        -623.13252382,  329.71293629,   45.36745942,  261.80202595,
#         678.12297566,   20.78701291])

# %%
lm.intercept_
# Out:
# 152.14906014576312

# %%
lm.score(x_train,y_train)
# Out:
# 0.4737305711504321

# %%
pred = lm.predict(x_test)

# %%
print("predicted",pred)
print("actual",y_test)
# Out:
# predicted [217.41788749 178.57584445 195.43768057 187.38080047 231.60585282
#  125.8593604  100.79884326 116.36587465  51.05966439  56.42469979
#  194.35235843 122.24120533  85.91778548  71.07106439 216.49266072
#  189.11825542  95.03725123  81.15652787 123.73158593 102.39836337
#  111.56733227 296.3630938  218.69215551 166.45507252 158.33368024
#  113.4293818  171.99129293 132.2530044  101.47325934 226.95396141
#   77.14812854  58.83827123 172.91727135 199.35363131 162.02589903
#   89.69971658 115.25849662 134.56630036 121.13284204 217.19332201
#   57.2714513  181.83539376 134.23112849 100.54494634 144.44641187
#  257.91560595 170.21460385 139.63016776 153.69952769  81.36493163
#  122.60275684 176.53030146 109.11857253 209.24275498 190.26166859
#  158.84084847 127.73951756 165.45153755 127.86572965 215.65851916
#  224.62087979  50.21840033 151.88201163 127.1285779  235.61171379
#  120.83463762  65.90919513  96.10635842 123.83805369 240.83929689
# ...

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.556992520181776

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
alphas = {'alpha':[1,0.1,0.001,0.0001,0]}
model = Ridge()

# %%
grid = GridSearchCV(estimator = model, param_grid= alphas)

# %%
grid.fit(x,y)
print(grid)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [1, 0.1, 0.001, 0.0001, 0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid.best_score_)
# Out:
# 0.47778722451749556

# %%
print(grid.best_estimator_.alpha)
# Out:
# 0.1

# %%
print(grid.best_params_)
# Out:
# {'alpha': 0.1}

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
grid_param = {'criterion':['gini','entropy']}
gd_sr = GridSearchCV(estimator = dtc, param_grid= grid_param,scoring ='accuracy', cv = 5)
gd_sr.fit(x,y)
# Out:
# C:\Users\Amitesh.Patel\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
# ...

# %%
best_parameters =gd_sr.best_params_
print(best_parameters)
best_results = gd_sr.best_score_
print(best_results)
# Out:
# {'criterion': 'entropy'}
# 0.011627906976744186

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model = AdaBoostRegressor()
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
# Out:
# 0.6842775938654725

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([239.66666667, 141.0990099 , 209.28947368, 213.14285714,
#        228.05797101, 106.94736842, 105.58823529, 108.08064516,
#         98.53409091, 104.41237113, 221.17647059, 125.95652174,
#        106.33333333, 108.40458015, 228.6097561 , 202.83146067,
#        105.58823529, 104.41237113, 105.29      , 106.33333333,
#        105.29      , 244.7804878 , 187.27118644, 131.0887574 ,
#        126.41463415, 104.57831325, 167.44117647, 205.30645161,
#        105.29      , 256.61764706,  98.57281553, 105.29      ,
#        209.61818182, 215.50892857, 155.25      , 110.5503876 ,
#        107.53846154, 148.39252336, 104.41237113, 202.84615385,
#        105.29      , 149.92857143, 151.68      , 106.33333333,
#        183.60714286, 215.50892857, 194.69291339, 155.61111111,
#        167.25555556, 106.33333333, 134.75862069, 148.39252336,
#        188.0625    , 207.26415094, 215.01052632, 193.26315789,
#        111.83333333, 188.89361702, 131.0887574 , 199.        ,
# ...

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-e18f5cbfd57d> in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_test,y_pred))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ...

# %%
from sklearn.externals import joblib
joblib.dump(model,'Project7_Diabetes.pkl')
# Out:
# ['Project7_Diabetes.pkl']
